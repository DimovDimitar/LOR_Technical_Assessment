# %%
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt
os.chdir(r"C:\Users\dimit\Desktop\Laing O'Rourke Tech Assessment")

data = pd.read_excel("Online Retail.xlsx", parse_dates=["InvoiceDate"])

data.info()

data.InvoiceNo.str.contains("C").sum()
data = data[data.InvoiceNo.astype(str).str.contains("C") == False]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 532621 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    532621 non-null  object
#  1   StockCode    532621 non-null  object
#  2   Description  531167 non-null  object
#  3   Quantity     532621 non-null  int64
#  4   InvoiceDate  532621 non-null  datetime64[ns]
#  5   UnitPrice    532621 non-null  float64
#  6   CustomerID   397924 non-null  float64
#  7   Country      532621 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 36.6+ MB

# %%
data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
data_copy=data

# %%
data_copy[data_copy['UnitPrice']>100].groupby(["StockCode"]).tail(20)
# Out:
#        InvoiceNo  StockCode                    Description  Quantity  \
# 15017     537632  AMAZONFEE                     AMAZON FEE         1
# 19428     537859      22828   REGENCY MIRROR WITH SHUTTERS         1
# 25168     538354      22826  LOVE SEAT ANTIQUE WHITE METAL         2
# 28902     538662      22656   VINTAGE BLUE KITCHEN CABINET         2
# 31614     538999      22656   VINTAGE BLUE KITCHEN CABINET         2
# ...          ...        ...                            ...       ...
# 536834    581219        DOT                 DOTCOM POSTAGE         1
# 537254    581238        DOT                 DOTCOM POSTAGE         1
# 539368    581439        DOT                 DOTCOM POSTAGE         1
# 540908    581492        DOT                 DOTCOM POSTAGE         1
# 541540    581498        DOT                 DOTCOM POSTAGE         1
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 15017  2010-12-07 15:08:00   13541.33         NaN  United Kingdom
# ...

# %%
data_copy[data_copy['UnitPrice']>1000].groupby(["StockCode"]).tail(20)
# Out:
#        InvoiceNo  StockCode      Description  Quantity         InvoiceDate  \
# 15017     537632  AMAZONFEE       AMAZON FEE         1 2010-12-07 15:08:00
# 119632    546558          M           Manual         1 2011-03-15 09:50:00
# 144826    548813          M           Manual         1 2011-04-04 13:03:00
# 144828    548813          M           Manual         1 2011-04-04 13:03:00
# 144829    548820          M           Manual         1 2011-04-04 13:04:00
# 145831    548913          M           Manual         1 2011-04-05 09:45:00
# 150615    549468          M           Manual         1 2011-04-08 14:27:00
# 173382    551697       POST          POSTAGE         1 2011-05-03 13:46:00
# 200745    554155          M           Manual         1 2011-05-23 11:26:00
# 201553    554301          M           Manual         1 2011-05-23 14:46:00
# 232891    557377          M           Manual         1 2011-06-20 11:00:00
# ...

# %%
data_copy[data_copy['UnitPrice']>500].groupby(["StockCode"]).tail(20)
# Out:
#        InvoiceNo  StockCode                     Description  Quantity  \
# 15017     537632  AMAZONFEE                      AMAZON FEE         1
# 173382    551697       POST                         POSTAGE         1
# 187584    552980       POST                         POSTAGE         1
# 222680    556444      22502  PICNIC BASKET WICKER 60 PIECES        60
# 222682    556446      22502  PICNIC BASKET WICKER 60 PIECES         1
# 236402    557754       POST                         POSTAGE         1
# 242907    558381          M                          Manual         1
# 264976    560187       POST                         POSTAGE         1
# 268028    560373          M                          Manual         1
# 268371    560411          M                          Manual         1
# 268399    560413          M                          Manual         1
# 268430    560419          M                          Manual         1
# ...

# %%
data = data[~data['StockCode'].isin(['DOT',"POST", "M", "B", "AMAZONFEE"])]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 530450 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    530450 non-null  object
#  1   StockCode    530450 non-null  object
#  2   Description  529001 non-null  object
#  3   Quantity     530450 non-null  int64
#  4   InvoiceDate  530450 non-null  datetime64[ns]
#  5   UnitPrice    530450 non-null  float64
#  6   CustomerID   396519 non-null  float64
#  7   Country      530450 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 36.4+ MB

# %%
data.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  530450.000000  530450.000000  396519.000000
# mean       10.252768       3.263790   15301.351718
# std       159.863878       4.444612    1709.777503
# min     -9600.000000       0.000000   12346.000000
# 25%         1.000000       1.250000   13975.000000
# 50%         3.000000       2.080000   15159.000000
# 75%        10.000000       4.130000   16801.000000
# max     80995.000000     649.500000   18287.000000

# %%
data = data[data['Quantity']>0]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 529114 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    529114 non-null  object
#  1   StockCode    529114 non-null  object
#  2   Description  528527 non-null  object
#  3   Quantity     529114 non-null  int64
#  4   InvoiceDate  529114 non-null  datetime64[ns]
#  5   UnitPrice    529114 non-null  float64
#  6   CustomerID   396519 non-null  float64
#  7   Country      529114 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 36.3+ MB

# %%
data.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  529114.000000  529114.000000  396519.000000
# mean       10.669795       3.272031   15301.351718
# std       157.094645       4.447189    1709.777503
# min         1.000000       0.000000   12346.000000
# 25%         1.000000       1.250000   13975.000000
# 50%         3.000000       2.080000   15159.000000
# 75%        11.000000       4.130000   16801.000000
# max     80995.000000     649.500000   18287.000000

# %%
data['TotalSales'] = data['Quantity'].multiply(data['UnitPrice'])

# %%
data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  TotalSales
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom       15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom       22.00
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34

# %%
print("Number of transactions: ", data['InvoiceNo'].nunique())
print("Number of products bought: ",data['StockCode'].nunique())
print("Number of customers:", data['CustomerID'].nunique() )
print("Percentage of customers NA: ", round(data['CustomerID'].isnull().sum() * 100 / len(data),2),"%" )
# Out:
# Number of transactions:  20558
# Number of products bought:  3936
# Number of customers: 4336
# Percentage of customers NA:  25.06 %

# %%
data[data["Quantity"]>5000]
# Out:
#        InvoiceNo StockCode                     Description  Quantity  \
# 61619     541431     23166  MEDIUM CERAMIC TOP STORAGE JAR     74215
# 74614     542504     37413                             NaN      5568
# 502122    578841     84826  ASSTD DESIGN 3D PAPER STICKERS     12540
# 540421    581483     23843     PAPER CRAFT , LITTLE BIRDIE     80995
#
#                InvoiceDate  UnitPrice  CustomerID         Country  TotalSales
# 61619  2011-01-18 10:01:00       1.04     12346.0  United Kingdom     77183.6
# 74614  2011-01-28 12:03:00       0.00         NaN  United Kingdom         0.0
# 502122 2011-11-25 15:57:00       0.00     13256.0  United Kingdom         0.0
# 540421 2011-12-09 09:15:00       2.08     16446.0  United Kingdom    168469.6

# %%
data = data[data.Quantity < 5000]dataset['InvoiceDate'].max()

Out[16]:

Timestamp('2011-12-09 12:50:00')

In [17]:

now = dt.date(2011,12,9)
print(now)

2011-12-09

In [18]:

#create a new column called date which contains the only the date of invoice
dataset['date'] = dataset['InvoiceDate'].dt.date

# %%
data.describe()
# Out:
#             Quantity     UnitPrice     CustomerID     TotalSales
# count  529110.000000  529110.00000  396516.000000  529110.000000
# mean       10.342311       3.27205   15301.361443      18.963443
# std        39.009486       4.44720    1709.773478      84.162558
# min         1.000000       0.00000   12347.000000       0.000000
# 25%         1.000000       1.25000   13975.000000       3.750000
# 50%         3.000000       2.08000   15159.000000       9.900000
# 75%        11.000000       4.13000   16801.000000      17.400000
# max      4800.000000     649.50000   18287.000000   38970.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 529110 entries, 0 to 541908
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    529110 non-null  object
#  1   StockCode    529110 non-null  object
#  2   Description  528524 non-null  object
#  3   Quantity     529110 non-null  int64
#  4   InvoiceDate  529110 non-null  datetime64[ns]
#  5   UnitPrice    529110 non-null  float64
#  6   CustomerID   396516 non-null  float64
#  7   Country      529110 non-null  object
#  8   TotalSales   529110 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(4)
# memory usage: 40.4+ MB

# %%
print (data.Description.isnull().sum())
# Out:
# 586

# %%
data = data[data.Description.isnull() == False]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 528524 entries, 0 to 541908
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    528524 non-null  object
#  1   StockCode    528524 non-null  object
#  2   Description  528524 non-null  object
#  3   Quantity     528524 non-null  int64
#  4   InvoiceDate  528524 non-null  datetime64[ns]
#  5   UnitPrice    528524 non-null  float64
#  6   CustomerID   396516 non-null  float64
#  7   Country      528524 non-null  object
#  8   TotalSales   528524 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(4)
# memory usage: 40.3+ MB

# %%
products_database = data 
customers_database = data[data.CustomerID.isnull() == False]

# %%
customers_database['InvoiceDate'].max()
# Out:
# Timestamp('2011-12-09 12:50:00')

# %%
now = dt.date(2011,12,9)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-cd86b7e91aff> in <module>
# ----> 1 now = dt.date(2011,12,9)
#
# NameError: name 'dt' is not defined

# %%
import datetime as dt

# %%
now = dt.date(2011,12,9)

# %%
customers_database['Date'] = customers_database['InvoiceDate'].dt.date
# Out:
# C:\Users\dimit\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
customers_database.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  TotalSales  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom       15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom       22.00
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
#
#          Date
# 0  2010-12-01
# 1  2010-12-01
# 2  2010-12-01
# 3  2010-12-01
# 4  2010-12-01

# %%
recency_data = customers_database.groupby(by='CustomerID', as_index=False)['Date'].max()
recency_data.columns = ['CustomerID','LastPurshaceDate']
recency_data.head()
# Out:
#    CustomerID LastPurshaceDate
# 0     12347.0       2011-12-07
# 1     12348.0       2011-09-25
# 2     12349.0       2011-11-21
# 3     12350.0       2011-02-02
# 4     12352.0       2011-11-03

# %%
recency_data['Recency'] = recency_data['LastPurshaceDate'].apply(lambda x: (now - x).days)

# %%
recency_data.head()
# Out:
#    CustomerID LastPurshaceDate  Recency
# 0     12347.0       2011-12-07        2
# 1     12348.0       2011-09-25       75
# 2     12349.0       2011-11-21       18
# 3     12350.0       2011-02-02      310
# 4     12352.0       2011-11-03       36
